# %%
from funcoes import *
from fluxo import *
import pandas as pd     
import time

# %%
df_matriz = pd.read_excel(r"C:\Users\manoel.campos\OneDrive - SFIEMT\Área de Trabalho\AutomatizacaoERP\Base_RAs\teste.xlsx")
display(df_matriz)
# Out:
#    CodFilialSGE        NomeCentroCusto          NomeModalidade     CodTurma  \
# 0             7          SENAI CACERES  TÉCNICO DE NÍVEL MÉDIO  TEC.199.011
# 1             7          SENAI CACERES  TÉCNICO DE NÍVEL MÉDIO  TEC.199.014
# 2             4     SENAI RONDONOPOLIS  TÉCNICO DE NÍVEL MÉDIO  TEC.199.006
# 3             4     SENAI RONDONOPOLIS  TÉCNICO DE NÍVEL MÉDIO  TEC.199.006
# 4            14  SENAI BARRA DO BUGRES  TÉCNICO DE NÍVEL MÉDIO  TEC.199.096
# 5            14  SENAI BARRA DO BUGRES  TÉCNICO DE NÍVEL MÉDIO  TEC.199.096
#
#    CodMatriculaSi     CodAlunoSi  RegistroAluno  \
# 0     64528863733  SGEMT00645288         645288
# 1     64172563737  SGEMT00641725         641725
# 2     64496163668  SGEMT00644961         644961
# 3     64496663668  SGEMT00644966         644966
# 4     64747164334  SGEMT00647471         647471
# 5     64744264334  SGEMT00647442         647442
#
#                        NomeAluno  TemParceria  OrigemParceria  \
# ...

# %%
print(df_matriz.columns)
# Out:
# Index(['CodFilialSGE', 'NomeCentroCusto', 'NomeModalidade', 'CodTurma',
#        'CodMatriculaSi', 'CodAlunoSi', 'RegistroAluno', 'NomeAluno',
#        'TemParceria', 'OrigemParceria', 'NomeInstituicaoOrigem', 'Convenio'],
#       dtype='str')

# %%
df_matriz.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CodFilialSGE           6 non-null      int64
#  1   NomeCentroCusto        6 non-null      str
#  2   NomeModalidade         6 non-null      str
#  3   CodTurma               6 non-null      str
#  4   CodMatriculaSi         6 non-null      int64
#  5   CodAlunoSi             6 non-null      str
#  6   RegistroAluno          6 non-null      int64
#  7   NomeAluno              6 non-null      str
#  8   TemParceria            6 non-null      int64
#  9   OrigemParceria         6 non-null      int64
#  10  NomeInstituicaoOrigem  0 non-null      float64
#  11  Convenio               6 non-null      str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 1.6 KB

# %%
#python
cod_filial = []

for x in df_matriz["CodFilialSGE"]:
    cod_filial.append(x)
    
cod_filal_unique = list(dict.fromkeys(cod_filial))    
print(cod_filal_unique)
# Out:
# [7, 4, 14]

# %%
#pandas
cod_filial_unique = df_matriz["CodFilialSGE"].drop_duplicates().tolist()
display(cod_filial_unique)
# Out:
# [7, 4, 14]

# %%
for filial in cod_filial_unique:

    df_filtrada = df_matriz[
        df_matriz["CodFilialSGE"] == filial
    ]
    

    display(df_filtrada)
# Out:
#    CodFilialSGE NomeCentroCusto          NomeModalidade     CodTurma  \
# 0             7   SENAI CACERES  TÉCNICO DE NÍVEL MÉDIO  TEC.199.011
# 1             7   SENAI CACERES  TÉCNICO DE NÍVEL MÉDIO  TEC.199.014
#
#    CodMatriculaSi     CodAlunoSi  RegistroAluno                    NomeAluno  \
# 0     64528863733  SGEMT00645288         645288      IZABELA DE FREITAS RICO
# 1     64172563737  SGEMT00641725         641725  LUIZ OTÁVIO NOBREGA HODNIUK
#
#    TemParceria  OrigemParceria  NomeInstituicaoOrigem  \
# 0            1               2                    NaN
# 1            1               2                    NaN
#
#                                             Convenio
# 0  NOVÍSSIMO ENSINO MÉDIO -  C1 -1000h   CRT010/2...
# 1  NOVÍSSIMO ENSINO MÉDIO -  C1 -1000h   CRT010/2...
#    CodFilialSGE     NomeCentroCusto          NomeModalidade     CodTurma  \
# 2             4  SENAI RONDONOPOLIS  TÉCNICO DE NÍVEL MÉDIO  TEC.199.006
# ...

# %%
for filial in cod_filial_unique:

    df_filtrada = df_matriz[
        df_matriz["CodFilialSGE"] == filial
    ]

    display(df_filtrada)
# Out:
#    CodFilialSGE NomeCentroCusto          NomeModalidade     CodTurma  \
# 0             7   SENAI CACERES  TÉCNICO DE NÍVEL MÉDIO  TEC.199.011
# 1             7   SENAI CACERES  TÉCNICO DE NÍVEL MÉDIO  TEC.199.014
#
#    CodMatriculaSi     CodAlunoSi  RegistroAluno                    NomeAluno  \
# 0     64528863733  SGEMT00645288         645288      IZABELA DE FREITAS RICO
# 1     64172563737  SGEMT00641725         641725  LUIZ OTÁVIO NOBREGA HODNIUK
#
#    TemParceria  OrigemParceria  NomeInstituicaoOrigem  \
# 0            1               2                    NaN
# 1            1               2                    NaN
#
#                                             Convenio
# 0  NOVÍSSIMO ENSINO MÉDIO -  C1 -1000h   CRT010/2...
# 1  NOVÍSSIMO ENSINO MÉDIO -  C1 -1000h   CRT010/2...
#    CodFilialSGE     NomeCentroCusto          NomeModalidade     CodTurma  \
# 2             4  SENAI RONDONOPOLIS  TÉCNICO DE NÍVEL MÉDIO  TEC.199.006
# ...
